# %%
# install requirements:
# !pip install -r requirements.txt

# %%
from utils import set_parameters, get_data, add_multiple, run_simulation, plot_example_period

# %% [markdown]
# ## Parameters

# %%
set_parameters(
    n_years=25,
    start_capital=1000,
    leverage_values=(1, 1.5, 2),  # (values below 1 also work)
    interest_percent=1,   # cost of leverage
    n_simulations=500
)

# %% [markdown]
# ## Simulation

# %%
data = add_multiple(get_data())
run_simulation(data, y_max_quantile_limit=0.9)
# Out:
# Running simulations: 100%|██████████| 500/500 [02:45<00:00,  3.02it/s]

# %%
plot_example_period(data)
